# %% [markdown]
# #### Specify MRI file

# %%
# Specify MRI file
mri_file = "../Datasets/ADNI_002_S_0295_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070802163833409_S32678_I64025.nii.gz"

# %% [markdown]
# #### Run process

# %%
# %run "ad_detection.py" $mri_file
# Out:
# [+] MRI file to be processed: ADNI_002_S_0295_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070802163833409_S32678_I64025.nii.gz
# [+] MRI cleaned
# [+] CNN model loaded
# RESULT: Model has predicted that the MRI is cognitively normal
#
# Run time:  28.804882764816284

# %%
import cv2

# Plot figure
fig, axes = plt.subplots(1, 2, figsize = (15,10));
slice_count = 80

volume_slice = volume[0, :, slice_count, :]
heatmap_slice = conv_heatmap[:, slice_count, :]
overlay_slice = cv2.addWeighted(volume_slice, 0.6, heatmap_slice, 0.4, 0)

axes[0].imshow(volume_slice, cmap='gray');
axes[1].imshow(overlay_slice,cmap='jet');
